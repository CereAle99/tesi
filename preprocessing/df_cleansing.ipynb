# %%
import os
import csv
import pandas as pd

# %%
total_index = pd.read_csv("../data/tot_MM_patientes.csv", sep=',')

tot_feat_index = pd.read_csv("../data/raw_MM_PT_feats.csv", sep=',')

# %%
tot_feat_index = tot_feat_index.drop("Unnamed: 0", axis=1)

# %%
original_feats = tot_feat_index[tot_feat_index["mask_shape"] == "original"]
fill_holes_feats = tot_feat_index[tot_feat_index["mask_shape"] == "fill_holes"]
dilation_feats = tot_feat_index[tot_feat_index["mask_shape"] == "dilation"]

# %%
original_feats
# Out:
#             patient_id mask_shape diagnostics_Versions_PyRadiomics  \
# 0     MPC_343_20191108   original                           v3.0.1
# 1      MPC_31_20121123   original                           v3.0.1
# 2     MPC_206_20160330   original                           v3.0.1
# 3    MPC_3338_20210628   original                           v3.0.1
# 4     MPC_148_20170607   original                           v3.0.1
# ..                 ...        ...                              ...
# 738   MPC_367_20160905   original                           v3.0.1
# 741   MPC_224_20160118   original                           v3.0.1
# 744                 P1   original                           v3.0.1
# 747   MPC_249_20130306   original                           v3.0.1
# 750   MPC_123_20210818   original                           v3.0.1
#
#     diagnostics_Versions_Numpy diagnostics_Versions_SimpleITK  \
# 0                       1.26.0                          2.3.1
# 1                       1.26.0                          2.3.1
# 2                       1.26.0                          2.3.1
# 3                       1.26.0                          2.3.1
# 4                       1.26.0                          2.3.1
# ..                         ...                            ...
# 738                     1.26.0                          2.3.1
# 741                     1.26.0                          2.3.1
# 744                     1.26.0                          2.3.1
# 747                     1.26.0                          2.3.1
# 750                     1.26.0                          2.3.1
#
#     diagnostics_Versions_PyWavelet diagnostics_Versions_Python  \
# 0                            1.5.0                     3.10.13
# 1                            1.5.0                     3.10.13
# 2                            1.5.0                     3.10.13
# 3                            1.5.0                     3.10.13
# 4                            1.5.0                     3.10.13
# ..                             ...                         ...
# 738                          1.5.0                     3.10.13
# 741                          1.5.0                     3.10.13
# 744                          1.5.0                     3.10.13
# 747                          1.5.0                     3.10.13
# 750                          1.5.0                     3.10.13
#
#                     diagnostics_Configuration_Settings  \
# 0    {'minimumROIDimensions': 2, 'minimumROISize': ...
# 1    {'minimumROIDimensions': 2, 'minimumROISize': ...
# 2    {'minimumROIDimensions': 2, 'minimumROISize': ...
# 3    {'minimumROIDimensions': 2, 'minimumROISize': ...
# 4    {'minimumROIDimensions': 2, 'minimumROISize': ...
# ..                                                 ...
# 738  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 741  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 744  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 747  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 750  {'minimumROIDimensions': 2, 'minimumROISize': ...
#
#            diagnostics_Configuration_EnabledImageTypes  \
# 0    {'Original': {}, 'Wavelet': {}, 'LoG': {'sigma...
# 1    {'Original': {}, 'Wavelet': {}, 'LoG': {'sigma...
# 2    {'Original': {}, 'Wavelet': {}, 'LoG': {'sigma...
# 3    {'Original': {}, 'Wavelet': {}, 'LoG': {'sigma...
# 4    {'Original': {}, 'Wavelet': {}, 'LoG': {'sigma...
# ..                                                 ...
# 738  {'Original': {}, 'Wavelet': {}, 'LoG': {'sigma...
# 741  {'Original': {}, 'Wavelet': {}, 'LoG': {'sigma...
# 744  {'Original': {}, 'Wavelet': {}, 'LoG': {'sigma...
# 747  {'Original': {}, 'Wavelet': {}, 'LoG': {'sigma...
# 750  {'Original': {}, 'Wavelet': {}, 'LoG': {'sigma...
#
#               diagnostics_Image-original_Hash  ...  \
# 0    71f724ffd7bb92fa64404934d2caf9adc157aa4c  ...
# 1    359f0b717bc84307c5219ce6dcdb8f352c9ad499  ...
# 2    2d466d0fcd121da869154d942ea46f62093f0f8c  ...
# 3    cd80ce6b3902200a626bbb3cc847076667fa406d  ...
# 4    b4d5f13ace97319f1a3e1260ab72439ad06558bf  ...
# ..                                        ...  ...
# 738  cda4554908ba8862ac766bc12231333c3bd19490  ...
# 741  3a55cb1581b8bc38792d6c77b532f67243b055a8  ...
# 744  8d1da07fd3b705db42e6adaded0a361c3fa698ba  ...
# 747  d74850e2ca1e841bf545406751774f5b6430fadf  ...
# 750  e21cf82648193e34e8d7721129a35f8c07853153  ...
#
#     log-sigma-2-0-mm-3D_gldm_GrayLevelNonUniformity  \
# 0                                        167.932667
# 1                                        138.611194
# 2                                        126.465817
# 3                                        210.649787
# 4                                        427.728537
# ..                                              ...
# 738                                      179.364882
# 741                                      140.923501
# 744                                      147.716921
# 747                                      322.620067
# 750                                      212.391239
#
#     log-sigma-2-0-mm-3D_gldm_GrayLevelVariance  \
# 0                                   943.717594
# 1                                  1803.783704
# 2                                  1364.358760
# 3                                   610.501369
# 4                                   249.130527
# ..                                         ...
# 738                                1310.068905
# 741                                1670.012289
# 744                                1284.242589
# 747                                 417.156435
# 750                                1248.555471
#
#     log-sigma-2-0-mm-3D_gldm_HighGrayLevelEmphasis  \
# 0                                     1.939636e+05
# 1                                     7.618197e+04
# 2                                     5.160601e+04
# 3                                     3.614113e+04
# 4                                     6.690081e+04
# ..                                             ...
# 738                                   8.328738e+04
# 741                                   1.448194e+05
# 744                                   6.888217e+04
# 747                                   1.690766e+04
# 750                                   2.031362e+06
#
#      log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis  \
# 0                                            1.945158
# 1                                            1.628388
# 2                                            1.919018
# 3                                            2.170259
# 4                                            3.355678
# ..                                                ...
# 738                                          1.748787
# 741                                          1.745272
# 744                                          1.910443
# 747                                          2.599402
# 750                                          1.867823
#
#      log-sigma-2-0-mm-3D_gldm_LargeDependenceHighGrayLevelEmphasis  \
# 0                                         3.862085e+05
# 1                                         1.279645e+05
# 2                                         1.052727e+05
# 3                                         8.190763e+04
# 4                                         2.302661e+05
# ..                                                 ...
# 738                                       1.501913e+05
# 741                                       2.591306e+05
# 744                                       1.375181e+05
# 747                                       4.683789e+04
# 750                                       3.822374e+06
#
#      log-sigma-2-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis  \
# 0                                             0.000069
# 1                                             0.000075
# 2                                             0.000107
# 3                                             0.000121
# 4                                             0.000101
# ..                                                 ...
# 738                                           0.000069
# 741                                           0.000066
# 744                                           0.000087
# 747                                           0.000206
# 750                                           0.000048
#
#     log-sigma-2-0-mm-3D_gldm_LowGrayLevelEmphasis  \
# 0                                        0.000065
# 1                                        0.000067
# 2                                        0.000090
# 3                                        0.000090
# 4                                        0.000066
# ..                                            ...
# 738                                      0.000061
# 741                                      0.000061
# 744                                      0.000075
# 747                                      0.000116
# 750                                      0.000048
#
#     log-sigma-2-0-mm-3D_gldm_SmallDependenceEmphasis  \
# 0                                           0.818926
# 1                                           0.868640
# 2                                           0.827437
# 3                                           0.783465
# 4                                           0.658212
# ..                                               ...
# 738                                         0.847781
# 741                                         0.850244
# 744                                         0.822411
# 747                                         0.733562
# 750                                         0.827749
#
#     log-sigma-2-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis  \
# 0                                         1.573483e+05
# 1                                         6.542398e+04
# 2                                         4.169966e+04
# 3                                         2.778048e+04
# 4                                         4.340904e+04
# ..                                                 ...
# 738                                       6.977809e+04
# 741                                       1.219838e+05
# 744                                       5.562321e+04
# 747                                       1.201946e+04
# 750                                       1.676585e+06
#
#     log-sigma-2-0-mm-3D_gldm_SmallDependenceLowGrayLevelEmphasis
# 0                                             0.000064
# 1                                             0.000065
# 2                                             0.000087
# 3                                             0.000084
# 4                                             0.000061
# ..                                                 ...
# 738                                           0.000059
# 741                                           0.000060
# 744                                           0.000072
# 747                                           0.000101
# 750                                           0.000048
#
# [261 rows x 1021 columns]

# %%
original_feats = original_feats.sort_values('patient_id')
original_feats = original_feats.drop_duplicates('patient_id', keep='last')
fill_holes_feats = fill_holes_feats.sort_values('patient_id')
fill_holes_feats = fill_holes_feats.drop_duplicates('patient_id', keep='last')
dilation_feats = dilation_feats.sort_values('patient_id')
dilation_feats = dilation_feats.drop_duplicates('patient_id', keep='last')

# %%
original_feats.to_csv("../data/MM_PET_feats_orig.csv", index=False, index_label="patient_id")
fill_holes_feats.to_csv("../data/MM_PT_feats_fill.csv", index=False, index_label="patient_id")
dilation_feats.to_csv("../data/MM_PT_feats_dil.csv", index=False, index_label="patient_id")

# %%
total_feats_df = pd.concat([original_feats, fill_holes_feats, dilation_feats], axis=0)
total_feats_df.to_csv("../data/MM_PT_feats.csv", index=False)
